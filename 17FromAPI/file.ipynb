# %%
import pandas as pd
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzNmNkZDI2YzFkYjNkNjRmMjM1ODY2ODQ5NTQ3ZTdiMyIsIm5iZiI6MTc2Nzc5MjI1NC44NCwic3ViIjoiNjk1ZTVlN2U1NDM3ZGRkN2QxY2VhYTcyIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.TRZFz1NvvdzSNA7SdlZ5CROAaZtOw5sdlcEhc0uiHQk"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":39.9435,"poster_path":"/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.713,"vote_count":29470},{"adult":false,"backdrop_path":"/tmU7GeKVybMWFButWEGl2M4GeiP.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fi
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)[['id', 'title', 'vote_average']]
# Out:
#     id                     title  vote_average
# 0  278  The Shawshank Redemption         8.713
# 1  238             The Godfather         8.685

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import pandas as pd
import time

session = requests.Session()

headers = {
    "Accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0MzRlZDNjMzkxMWYxODllY2E2YjBlZjIxOGVkYzcxZCIsIm5iZiI6MTc2Nzc5MjI1NC44NCwic3ViIjoiNjk1ZTVlN2U1NDM3ZGRkN2QxY2VhYTcyIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.b-CZkNqQdEzR3Bbc3BBjv8o4i9sn5AKCqkx9QJYodyk"

}


df = pd.DataFrame()

for i in range(1, 529):   # keep pages low while testing
    try:
        url = "https://api.themoviedb.org/3/movie/top_rated"
        params = {
            "language": "en-US",
            "page": i
        }

        response = session.get(
            url,
            headers=headers,
            params=params,
            timeout=10
        )

        response.raise_for_status()

        data = pd.DataFrame(response.json()["results"])[
            ["id", "title", "vote_average"]
        ]

        df = pd.concat([df, data], ignore_index=True)

        time.sleep(1.2)   # ⭐ VERY IMPORTANT

    except requests.exceptions.RequestException as e:
        print(f"Failed on page {i}: {e}")
        break

df.head()
# Out:
# Failed on page 501: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=501
#     id                     title  vote_average
# 0  278  The Shawshank Redemption         8.713
# 1  238             The Godfather         8.685
# 2  240     The Godfather Part II         8.600
# 3  424          Schindler's List         8.565
# 4  389              12 Angry Men         8.550

# %%
df.head(30)
# Out:
#         id                                              title  vote_average
# 0      278                           The Shawshank Redemption         8.713
# 1      238                                      The Godfather         8.685
# 2      240                              The Godfather Part II         8.600
# 3      424                                   Schindler's List         8.565
# 4      389                                       12 Angry Men         8.550
# 5      129                                      Spirited Away         8.534
# 6      155                                    The Dark Knight         8.525
# 7    19404                        Dilwale Dulhania Le Jayenge         8.516
# 8      497                                     The Green Mile         8.503
# 9   496243                                           Parasite         8.496
# 10     122      The Lord of the Rings: The Return of the King         8.492
# ...

# %%
import requests
import time

url = "https://weather-by-api-ninjas.p.rapidapi.com/v1/weather"
df=pd.DataFrame()
places = {
    "Delhi": (28.6139, 77.2090),
    "Mumbai": (19.0760, 72.8777),
    "Kolkata": (22.5726, 88.3639),
    "Chennai": (13.0827, 80.2707),
    "Seattle": (47.6062, -122.3321),
	"Durgapur": (23.5158, 87.3080)
}

headers = {
    "x-rapidapi-key": "fadd5b55e3mshe39e9fae39e4a96p1f6752jsn146f3e700958",
    "x-rapidapi-host": "weather-by-api-ninjas.p.rapidapi.com"
}

for city, (lat, lon) in places.items():
    params = {
        "lat": lat,
        "lon": lon
    }

    response = requests.get(url, headers=headers, params=params)
    data = response.json()

    temp=pd.DataFrame([data])[['temp','humidity','wind_speed','cloud_pct']]
    df=pd.concat([df,temp],ignore_index=True)

   

    time.sleep(1)  # prevents rate-limit issues

df.head()
# Out:
#    temp  humidity  wind_speed  cloud_pct
# 0     9        93        1.03          0
# 1    26        47        2.57          0
# 2    16        67        2.06          2
# 3    25        67        4.12         40
# 4     5        89        6.69         75

# %%
df.index=places.keys()
df
# Out:
#           temp  humidity  wind_speed  cloud_pct
# Delhi        9        93        1.03          0
# Mumbai      26        47        2.57          0
# Kolkata     16        67        2.06          2
# Chennai     25        67        4.12         40
# Seattle      5        89        6.69         75
# Durgapur    15        39        2.56          1
